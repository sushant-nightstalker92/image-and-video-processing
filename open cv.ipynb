# %%
import cv2 #opencv uge as cv2 in python
img1 = cv2.imread(r"C:\Users\chava\Pictures\Screenshots\Screenshot 2024-04-20 134543.png")
img1 = cv2.resize(img1, (480,280))#"widch ,height"
cv2.imshow("original",img1)
cv2.waitKey()
cv2. destroyAllWindows()

# %%
import cv2 #opencv uge as cv2 in python
img1 = cv2.imread(r"C:\Users\chava\Pictures\Screenshots\Screenshot 2024-04-20 134543.png",0)
img1 = cv2.resize(img1, (1260,700))#"widch ,height"
cv2.imshow("original",img1)
cv2.waitKey()
cv2. destroyAllWindows()

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\chava\Desktop\VID_20240613_161115.mp4")
print('cap',cap)
while True:
    ret,frame = cap.read()
    frame = cv2.resize(frame,(700,450))
    #hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV) use for covert colour
    cv2.imshow('frame',frame)
    k=cv2.waitKey(25)
    if k==ord('q'):
        break
cap.release()
cv2. destroyAllWindows()

# %% [markdown]
# # capture video from laptop camera

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)# for laptop camera we need 0 and external connected camera we need 1 in= videocapture()
fourcc=cv2.VideoWriter_fourcc(*'XVID')# for save video format XVID,DIVX,MGPG
output=cv2.VideoWriter(r'C:\Users\chava\Desktop\output.avi',fourcc,20.0,(640,480))# 20 for fram pre second (640,480) for video resolution
print('cap',cap)
while cap.isOpened():# .isOpened() function used for record video 
    ret,frame = cap.read()
    if ret==True:
        #hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV) use for covert colour
        cv2.imshow('frame',frame)
        output.write(frame)
        k=cv2.waitKey(25)# inside waitkey 0 for image and greater then 0 ,1 or 2,3,..100..for video
        if k==ord('q'):
            break
cap.release()
output.release()
cv2. destroyAllWindows()

# %% [markdown]
# # screen recording by using cv2

# %%
import cv2 as c
import pyautogui as p
import numpy as np
# create resolution
rs=p.size()
#file name which we want store
fn=input('enter any file name and path: ')
#fix fram rate
fps=60
fourcc = c.VideoWriter_fourcc(*'XVID')
output = c.VideoWriter(fn,fourcc,fps,rs)
#create recording module
c.namedWindow('live_recording',c.WINDOW_NORMAL)
c.resizeWindow('live_recording',(600,400))
while True:
    img=p.screenshot()
    f=np.array(img)
    f=c.cvtColor(f,c.COLOR_BGR2RGB)
    output.write(f)
    c.imshow('live_recording',f)
    if c.waitKey(1) & 0xFF == 27:
        break
        cv2.destroyAllWindows()
cap.release()        
output.release()
cv2.destroyAllWindows()

# %% [markdown]
# # break video into multiple images

# %%
import cv2
vidcap=cv2.VideoCapture(r"C:\Users\chava\Desktop\VID_20240613_161115.mp4")#input video for taking screenshot
ret,image=vidcap.read()#read video
count=0
while True:
    if ret==True:
        cv2.imwrite(r"C:\Users\chava\Desktop\frames\image%d.jpg"%count,image)#for giving path to save screenshot
        vidcap.set(cv2.CAP_PROP_POS_MSEC,(count**100))
        ret,image=vidcap.read()
        cv2.imshow('res',image)
        count+=1
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
            cv2.destroyAllWindows()
cap.release()        
output.release()
cv2.destroyAllWindows()

# %% [markdown]
# # open cv drawing function by using mouse right or left key

# %%
import numpy as np
import cv2



# mouse callback function
def draw(event,x,y,flags,param):
    
    if event == cv2.EVENT_LBUTTONDBLCLK:
        
        cv2.circle(img,(x,y),100,(125,0,255),5)
        
    if event == cv2.EVENT_RBUTTONDBLCLK:
        
        cv2.rectangle(img,(x,y),(x+100,y+75),(125,125,255),2)
cv2.namedWindow(winname = "res")    
# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)
cv2.setMouseCallback("res",draw)

while True:
    cv2.imshow("res",img)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cv2.destroyAllWindows()

# %% [markdown]
# # Create a fucntion which help to find cordinate of any pixel and its color

# %%
import cv2

def mouse_event(event, x, y, flg, param):
    print("event==",event)
    print("x==",x)
    print("y==",y)
    print("flg==",flg)
    print("param==",param)
    font = cv2.FONT_HERSHEY_PLAIN 
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,', ' ,y)
           
        cord = ". "+str(x) + ', '+ str(y)
        cv2.putText(img, cord, (x, y), font, 1, (155,125 ,100), 2)
        cv2.imshow('image', img)
    if event == cv2.EVENT_RBUTTONDOWN:
        b= img[y, x, 0] #for blue channel is 0
        g = img[y, x, 1] #for green channel is 1
        r = img[y, x, 2] #for red channel is 2
        
        color_bgr = ". "+str(b) + ', '+ str(g)+ ', '+ str(r)
        cv2.putText(img, color_bgr, (x, y), font, 1, (152, 255, 130), 2)
        cv2.imshow('image', img)

#img = np.zeros((512, 512, 3), np.uint8)
img = cv2.imread(r"C:\Users\chava\Desktop\WhatsApp Image 2024-02-07 at 13.28.20_2c2001cb.jpg")#enter path of image which we want to coordinate and pixle colour
cv2.imshow('image', img)

cv2.setMouseCallback('image', mouse_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Create your own color picker

# %%
import cv2
import numpy as np

def cross(x):
    pass
#create a black imgae
img = np.zeros((300,512,3),np.uint8) #empty image
cv2.namedWindow("Color Picker")

#Creating switch for on and of the trackbars
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'Color Picker',0,1,cross)

#Creating TrackBars For Adjusting Colors
cv2.createTrackbar("R","Color Picker",0,255,cross)
cv2.createTrackbar("G","Color Picker",0,255,cross)
cv2.createTrackbar("B","Color Picker",0,255,cross)

#Now creating logic to handle trackbars
while True:
    cv2.imshow("Color Picker",img)
    k = cv2.waitKey(1) & 0xFF
    if k==27: #for exit
        break
    
    #set current positions of four bars
    s = cv2.getTrackbarPos(switch,"Color Picker") #switch
    r = cv2.getTrackbarPos("R","Color Picker")
    g = cv2.getTrackbarPos("G","Color Picker")
    b = cv2.getTrackbarPos("B","Color Picker")
    
    if s==0:
        img[:] = 0
    else:
        img[:] = [r,g,b] #here openCV support BGR
cv2.destroyAllWindows()

# %% [markdown]
# ### Image Opeartions | cv2.split, cv2.merge, cv2.resize, cv2.add, cv2.addWeighted | Open CV

# %%
import cv2
import numpy as np

# Read an Image
img = cv2.imread(r"C:\Users\chava\Pictures\Screenshots\Screenshot 2024-04-20 134543.png")
img = cv2.resize(img, (600, 400))
cv2.imshow("res", img)
print("shape==", img.shape)  # returns a tuple of number of rows, columns, and channels
print("no.of pixels==", img.size)  # returns Total number of pixels
print("datatype==", img.dtype)  # returns Image datatype
print("Imagetype==", type(img))

# Split the image into its color channels
b, g, r = cv2.split(img)

# Create images with single channels highlighted
blue_img = cv2.merge([b, np.zeros_like(b), np.zeros_like(b)])
green_img = cv2.merge([np.zeros_like(g), g, np.zeros_like(g)])
red_img = cv2.merge([np.zeros_like(r), np.zeros_like(r), r])

cv2.imshow("blue", blue_img)
cv2.imshow("green", green_img)
cv2.imshow("red", red_img)
#show image in merge format
mr1 = cv2.merge((r,g,b))
cv2.imshow("rgb",mr1)
mr2 = cv2.merge((g,b,r))
cv2.imshow("gbr",mr2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### playing snake game by using laptop webcam and control by hand fingure of direction of snake

# %%
import cv2
import numpy as np
import mediapipe as mp
import random

# Initialize Mediapipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_drawing = mp.solutions.drawing_utils

# Game parameters
frame_width, frame_height = 640, 480
block_size = 20
initial_snake_length = 5
speed = 5

# Define colors
background_color = (0, 0, 0)
snake_color = (0, 255, 0)
food_color = (0, 0, 255)

# Generate food
def generate_food():
    x = random.randint(0, (frame_width // block_size) - 1) * block_size
    y = random.randint(0, (frame_height // block_size) - 1) * block_size
    return (x, y)

# Initialize snake and food
snake = [(block_size * i, block_size) for i in range(initial_snake_length, 0, -1)]
direction = (speed, 0)
food = generate_food()

# Setup webcam
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, frame_width)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, frame_height)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Flip the frame horizontally for a selfie-view display
    frame = cv2.flip(frame, 1)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(frame_rgb)

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Draw landmarks on the hand
            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            landmarks = hand_landmarks.landmark

            # Get coordinates for the tip of the index finger
            index_tip = landmarks[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            index_x = int(index_tip.x * frame_width)
            index_y = int(index_tip.y * frame_height)

            # Determine direction based on index finger position
            if index_y < frame_height // 3:
                direction = (0, -speed)  # Move up
            elif index_y > 2 * frame_height // 3:
                direction = (0, speed)  # Move down
            elif index_x < frame_width // 3:
                direction = (-speed, 0)  # Move left
            elif index_x > 2 * frame_width // 3:
                direction = (speed, 0)  # Move right

    frame_game = np.zeros((frame_height, frame_width, 3), dtype=np.uint8)
    
    # Draw food
    cv2.rectangle(frame_game, food, (food[0] + block_size, food[1] + block_size), food_color, -1)
    
    # Move snake
    head_x, head_y = snake[0]
    new_head = (head_x + direction[0], head_y + direction[1])
    snake = [new_head] + snake[:-1]
    
    # Check for collision with walls
    if new_head[0] < 0 or new_head[0] >= frame_width or new_head[1] < 0 or new_head[1] >= frame_height:
        break
    
    # Check for collision with itself
    if new_head in snake[1:]:
        break
    
    # Check for collision with food
    if new_head == food:
        snake.append(snake[-1])
        food = generate_food()
    
    # Draw snake
    for segment in snake:
        cv2.rectangle(frame_game, segment, (segment[0] + block_size, segment[1] + block_size), snake_color, -1)
    
    combined_frame = np.hstack((frame, frame_game))
    cv2.imshow("Snake Game", combined_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # counting finger by using laptop web cam

# %%
#Step - 1  -Import Libraries and capture camera
#Step - 2  -Convert frames Into hsv
#Step - 3  -Track hand on color basis 
#Step - 4  -Create mask on the basis of color and filter actual color 
#Step - 5  -Invert pixel value and then enchance the result for better output
#Step - 6  -Find Contours for specific colored object
#Step - 7  -Find Max area contour and draw it on live feed
#Step - 8  -Find Convexity detect  for counting Values and Apply Cosin method
#Step - 9  -Put Counting Values on fingers on the basis of convexity defects.
#Step -10  -Enjoy Your Output


#Counting Fingers only tutorials using open cv

#Step 1----------------------------------------
import cv2
import numpy as np 
import math

#Read Camera
cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
def nothing(x):
    pass
#window name
cv2.namedWindow("Color Adjustments",cv2.WINDOW_NORMAL)
cv2.resizeWindow("Color Adjustments", (300, 300)) 
cv2.createTrackbar("Thresh", "Color Adjustments", 0, 255, nothing)

#COlor Detection Track

cv2.createTrackbar("Lower_H", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_S", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_V", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Upper_H", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_S", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_V", "Color Adjustments", 255, 255, nothing)


while True:
    _,frame = cap.read()
    frame = cv2.flip(frame,2)
    frame = cv2.resize(frame,(600,500))
    # Get hand data from the rectangle sub window
    cv2.rectangle(frame, (0,1), (300,500), (255, 0, 0), 0)
    crop_image = frame[1:500, 0:300]
    
    # Step  - 2 - 
    hsv = cv2.cvtColor(crop_image, cv2.COLOR_BGR2HSV)
    #detecting hand
    l_h = cv2.getTrackbarPos("Lower_H", "Color Adjustments")
    l_s = cv2.getTrackbarPos("Lower_S", "Color Adjustments")
    l_v = cv2.getTrackbarPos("Lower_V", "Color Adjustments")

    u_h = cv2.getTrackbarPos("Upper_H", "Color Adjustments")
    u_s = cv2.getTrackbarPos("Upper_S", "Color Adjustments")
    u_v = cv2.getTrackbarPos("Upper_V", "Color Adjustments")
    
    #Step -3
    lower_bound = np.array([l_h, l_s, l_v])
    upper_bound = np.array([u_h, u_s, u_v])
    
    #step -4
    #Creating Mask
    mask = cv2.inRange(hsv, lower_bound, upper_bound)
    #filter mask with image
    filtr = cv2.bitwise_and(crop_image, crop_image, mask=mask)
    
    #step - 5 
    mask1  = cv2.bitwise_not(mask)
    m_g = cv2.getTrackbarPos("Thresh", "Color Adjustments") #getting track bar value
    ret,thresh = cv2.threshold(mask1,m_g,255,cv2.THRESH_BINARY)
    dilata = cv2.dilate(thresh,(3,3),iterations = 6)
    
    #step - 6 
    #findcontour(img,contour_retrival_mode,method)
    cnts,hier = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
    
    try:
        #print("try")
        
        #Step -7
        # Find contour with maximum area
        cm = max(cnts, key=lambda x: cv2.contourArea(x))
        #print("C==",cnts)
        epsilon = 0.0005*cv2.arcLength(cm,True)
        data= cv2.approxPolyDP(cm,epsilon,True)
        
        hull = cv2.convexHull(cm)
        
        cv2.drawContours(crop_image, [cm], -1, (50, 50, 150), 2)
        cv2.drawContours(crop_image, [hull], -1, (0, 255, 0), 2)
        
        #Step -8
        # Find convexity defects
        hull = cv2.convexHull(cm, returnPoints=False)
        defects = cv2.convexityDefects(cm, hull)
        count_defects = 0
        #print("Area==",cv2.contourArea(hull) - cv2.contourArea(cm))
        for i in range(defects.shape[0]):
            s,e,f,d = defects[i,0]
           
            start = tuple(cm[s][0])
            end = tuple(cm[e][0])
            far = tuple(cm[f][0])
            
            #Cosin Rule
            a = math.sqrt((end[0] - start[0]) ** 2 + (end[1] - start[1]) ** 2)
            b = math.sqrt((far[0] - start[0]) ** 2 + (far[1] - start[1]) ** 2)
            c = math.sqrt((end[0] - far[0]) ** 2 + (end[1] - far[1]) ** 2)
            angle = (math.acos((b ** 2 + c ** 2 - a ** 2) / (2 * b * c)) * 180) / 3.14
            #print(angle)
            # if angle > 50 draw a circle at the far point
            if angle <= 50:
                count_defects += 1
                cv2.circle(crop_image,far,5,[255,255,255],-1)
        
        print("count==",count_defects)
        
        #Step - 9
        # Print number of fingers
        if count_defects == 0:
            
            cv2.putText(frame, "1", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2)
        elif count_defects == 1:
            cv2.putText(frame, "2", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255), 2)
        elif count_defects == 2:
            
            cv2.putText(frame, "3", (5, 50), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255), 2)
        elif count_defects == 3:
            
            cv2.putText(frame, "4", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255), 2)
        elif count_defects == 4:
            
            cv2.putText(frame, "5", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255), 2)
        else:
            pass
           
    except:
        pass
        
    cv2.imshow("Thresh", thresh)
    #cv2.imshow("mask==",mask)
    cv2.imshow("filter==",filtr)
    cv2.imshow("Result", frame)

    key = cv2.waitKey(25) &0xFF
    if key == 27:
        break
cap.release()
cv2.destroyAllWindows()
